# %%
import pandas as pd
import numpy as np

df = pd.read_csv("/home/jdata/Escritorio/projects/dataAnalyst/dataPractices/crimenMeridaNOV2024.csv")

# %%
df.head(40)
# Out:
#    codigo     fecha                 descripcion             ubicación  \
# 0    c001  01/11/24          robo a mano armada  merida casco central
# 1    c002  02/11/24                       hurto  merida casco central
# 2    c003  03/11/24                       hurto  merida casco central
# 3    c004  04/11/24                       hurto  merida casco central
# 4    c005  05/11/24                  homicidio           los sausales
# 5    c006  06/11/24                   secuestro                 ejido
# 6    c007  07/11/24  acceso a propiedad privada              el valle
# 7    c008  08/11/24          robo a mano armada           san jacinto
# 8    c009  09/11/24                  homicidio                  ejido
# 9    c010  10/11/24                  homicidio                  ejido
# 10   c011  11/11/24          robo a mano armada                 ejido
# 11   c012  12/11/24          robo a mano armada                 ejido
# ...

# %%
#obteniendo correlacion entre las columnas conteo y alerta.

np.corrcoef(df["conteo"],df["alerta"])
# Out:
# array([[1.       , 0.5902264],
#        [0.5902264, 1.       ]])

# %%
df.drop(inplace = True, columns = ["descripcion","ubicación","impacto", "estado")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 df.drop(inplace = True, columns = ["descripcion","ubicación","impacto", "estado", "codigo", "fecha"])
#
# File ~/.local/lib/python3.13/site-packages/pandas/core/frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)   5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)   5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
# ...

# %%
df.drop(inplace = True, columns = ["fecha", "codigo"])

# %%
df.head()
# Out:
#    conteo  alerta
# 0     2.0     1.0
# 1     2.0     0.5
# 2     5.0     0.5
# 3     2.0     0.5
# 4     8.0     1.0

# %%
df.corr()
# Out:
#         conteo  alerta
# conteo     1.0    -1.0
# alerta    -1.0     1.0

# %%
corr = round(df.corr(),3)
corr.style.background_gradient() #pendiente no funciona
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~/.local/lib/python3.13/site-packages/IPython/core/formatters.py:406, in BaseFormatter.__call__(self, obj)
#     404     method = get_real_method(obj, self.print_method)
#     405     if method is not None:
# --> 406         return method()
#     407     return None
#     408 else:
#
# File ~/.local/lib/python3.13/site-packages/pandas/io/formats/style.py:405, in Styler._repr_html_(self)
#     400 """
#     401 Hooks into Jupyter notebook rich display system, which calls _repr_html_ by
#     402 default if an object is returned at the end of a cell.
#     403 """
#     404 if get_option("styler.render.repr") == "html":
# --> 405     return self.to_html()
#     406 return None
#
# ...
