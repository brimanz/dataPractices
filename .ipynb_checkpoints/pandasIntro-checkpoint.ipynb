# %%
import pandas as pd

df = pd.read_csv("/home/jdata/Escritorio/projects/cursoDataScience/2024.csv", nrows = 100)
df.head(10)
# Out:
#   Unnamed: 0                                Unnamed: 1          Unnamed: 2  \
# 0        NaN                                       NaN                 NaN
# 1        NaN  Delitos reportados mes de Noviembre 2024                 NaN
# 2        NaN                                       NaN                 NaN
# 3        NaN                                       NaN                 NaN
# 4        NaN                                       NaN                 NaN
# 5        NaN                                       NaN                 NaN
# 6        NaN                                       NaN                 NaN
# 7        NaN                                       NaN                 NaN
# 8     código                                     fecha         descripción
# 9       c001                                  01/11/24  robo a mano armada
#
#              Unnamed: 3 Unnamed: 4 Unnamed: 5  Unnamed: 6  \
# 0                   NaN        NaN        NaN         NaN
# ...

# %%
df.tail()
# Out:
#    Unnamed: 0 Unnamed: 1                  Unnamed: 2 Unnamed: 3    Unnamed: 4  \
# 41       c033   03/12/24          robo a mano armada    la vega  sin resolver
# 42       c034   04/12/24          robo a mano armada    la vega  sin resolver
# 43       c035   05/12/24  acceso a propiedad privada   el valle      resuelto
# 44       c036   06/12/24  acceso a propiedad privada   el valle      resuelto
# 45       c037   07/12/24  acceso a propiedad privada   el valle      resuelto
#
#    Unnamed: 5  Unnamed: 6 Unnamed: 7
# 41       alto         NaN        NaN
# 42       alto         NaN        NaN
# 43       bajo         NaN        NaN
# 44       bajo         NaN        NaN
# 45       bajo         NaN        NaN

# %%
df = df.sample(frac = 1)

df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Unnamed: 0     object
# Unnamed: 1     object
# Unnamed: 2     object
# Unnamed: 3     object
# Unnamed: 4     object
# Unnamed: 5     object
# Unnamed: 6    float64
# Unnamed: 7     object
# dtype: object
