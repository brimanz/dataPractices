# %%
import pandas as pd

df = pd.read_csv("/home/jdata/Escritorio/projects/dataAnalyst/dataPractices/crimenMeridaNOV2024.csv")
df.head(50)
# Out:
#    codigo     fecha                 descripcion             ubicación  \
# 0    c001  01/11/24          robo a mano armada  merida casco central
# 1    c002  02/11/24                       hurto  merida casco central
# 2    c003  03/11/24                       hurto  merida casco central
# 3    c004  04/11/24                       hurto  merida casco central
# 4    c005  05/11/24                  homicidio           los sausales
# 5    c006  06/11/24                   secuestro                 ejido
# 6    c007  07/11/24  acceso a propiedad privada              el valle
# 7    c008  08/11/24          robo a mano armada           san jacinto
# 8    c009  09/11/24                  homicidio                  ejido
# 9    c010  10/11/24                  homicidio                  ejido
# 10   c011  11/11/24          robo a mano armada                 ejido
# 11   c012  12/11/24          robo a mano armada                 ejido
# ...

# %%
#añadiendo columna

df["codigo2"] = round(df["codigo"] / 2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/.local/lib/python3.13/site-packages/pandas/core/ops/array_ops.py:218, in _na_arithmetic_op(left, right, op, is_cmp)
#     217 try:
# --> 218     result = func(left, right)
#     219 except TypeError:
#
# File ~/.local/lib/python3.13/site-packages/pandas/core/computation/expressions.py:242, in evaluate(op, a, b, use_numexpr)
#     240     if use_numexpr:
#     241         # error: "None" not callable
# --> 242         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     243 return _evaluate_standard(op, op_str, a, b)
#
# File ~/.local/lib/python3.13/site-packages/pandas/core/computation/expressions.py:73, in _evaluate_standard(op, op_str, a, b)
#      72     _store_test_result(False)
# ---> 73 return op(a, b)
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'
#
# ...

# %%
del(df["codigo"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.13/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'codigo'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 del(df["codigo"])
#
# ...

# %%
df.head()
# Out:
#       fecha         descripcion             ubicación        estado impacto
# 0  01/11/24  robo a mano armada  merida casco central      resuelto    alto
# 1  02/11/24               hurto  merida casco central      resuelto   medio
# 2  03/11/24               hurto  merida casco central      resuelto   medio
# 3  04/11/24               hurto  merida casco central      resuelto   medio
# 4  05/11/24          homicidio           los sausales  sin resolver    alto

# %%
#eliminando varias columnas.

df.drop(["impacto", "estado"], axis = 1)
# Out:
#        fecha                 descripcion             ubicación
# 0   01/11/24          robo a mano armada  merida casco central
# 1   02/11/24                       hurto  merida casco central
# 2   03/11/24                       hurto  merida casco central
# 3   04/11/24                       hurto  merida casco central
# 4   05/11/24                  homicidio           los sausales
# 5   06/11/24                   secuestro                 ejido
# 6   07/11/24  acceso a propiedad privada              el valle
# 7   08/11/24          robo a mano armada           san jacinto
# 8   09/11/24                  homicidio                  ejido
# 9   10/11/24                  homicidio                  ejido
# 10  11/11/24          robo a mano armada                 ejido
# 11  12/11/24          robo a mano armada                 ejido
# 12  13/11/24          robo a mano armada                 ejido
# 13  14/11/24                       hurto              el valle
# ...

# %%
df.head()
# Out:
#       fecha         descripcion             ubicación        estado impacto
# 0  01/11/24  robo a mano armada  merida casco central      resuelto    alto
# 1  02/11/24               hurto  merida casco central      resuelto   medio
# 2  03/11/24               hurto  merida casco central      resuelto   medio
# 3  04/11/24               hurto  merida casco central      resuelto   medio
# 4  05/11/24          homicidio           los sausales  sin resolver    alto

# %%
#eliminando varias columnas manera alternativa.

df.drop(["impacto", "estado"], axis = 1, implace = True)

# %%
#eliminando filas.

df.drop(30) #en esta caso eliminamos la fila numero 30
# Out:
#        fecha                 descripcion             ubicación        estado  \
# 0   01/11/24          robo a mano armada  merida casco central      resuelto
# 1   02/11/24                       hurto  merida casco central      resuelto
# 2   03/11/24                       hurto  merida casco central      resuelto
# 3   04/11/24                       hurto  merida casco central      resuelto
# 4   05/11/24                  homicidio           los sausales  sin resolver
# 5   06/11/24                   secuestro                 ejido  sin resolver
# 6   07/11/24  acceso a propiedad privada              el valle      resuelto
# 7   08/11/24          robo a mano armada           san jacinto      resuelto
# 8   09/11/24                  homicidio                  ejido  sin resolver
# 9   10/11/24                  homicidio                  ejido  sin resolver
# 10  11/11/24          robo a mano armada                 ejido  sin resolver
# ...
