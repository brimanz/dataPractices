# %%
import pandas as pd

df = pd.read_csv("/home/jdata/Escritorio/projects/dataAnalyst/dataPractices/crimenMeridaNOV2024.csv")
df.head(50)
# Out:
#    codigo     fecha                 descripcion             ubicación  \
# 0    c001  01/11/24          robo a mano armada  merida casco central
# 1    c002  02/11/24                       hurto  merida casco central
# 2    c003  03/11/24                       hurto  merida casco central
# 3    c004  04/11/24                       hurto  merida casco central
# 4    c005  05/11/24                  homicidio           los sausales
# 5    c006  06/11/24                   secuestro                 ejido
# 6    c007  07/11/24  acceso a propiedad privada              el valle
# 7    c008  08/11/24          robo a mano armada           san jacinto
# 8    c009  09/11/24                  homicidio                  ejido
# 9    c010  10/11/24                  homicidio                  ejido
# 10   c011  11/11/24          robo a mano armada                 ejido
# 11   c012  12/11/24          robo a mano armada                 ejido
# 12   c013  13/11/24          robo a mano armada                 ejido
# 13   c014  14/11/24                       hurto              el valle
# 14   c015  15/11/24                       hurto              el valle
# 15   c016  16/11/24          robo a mano armada               la vega
# 16   c017  17/11/24          robo a mano armada               la vega
# 17   c018  18/11/24          robo a mano armada               la vega
# 18   c019  19/11/24          robo a mano armada               la vega
# 19   c020  20/11/24  acceso a propiedad privada              el valle
# 20   c021  21/11/24  acceso a propiedad privada              el valle
# 21   c022  22/11/24  acceso a propiedad privada          el vallecito
# 22   c023  23/11/24  acceso a propiedad privada          el vallecito
# 23   c024  24/11/24                   secuestro                 ejido
# 24   c025  25/11/24                   secuestro                 ejido
# 25   c026  26/11/24                  homicidio                  ejido
# 26   c027  27/11/24                  homicidio                  ejido
# 27   c028  28/11/24                  homicidio                  ejido
# 28   c029  29/11/24                  homicidio                la vega
# 29   c030  30/11/24                  homicidio                la vega
# 30   c031  01/12/24          robo a mano armada               la vega
# 31   c032  02/12/24          robo a mano armada               la vega
# 32   c033  03/12/24          robo a mano armada               la vega
# 33   c034  04/12/24          robo a mano armada               la vega
# 34   c035  05/12/24  acceso a propiedad privada              el valle
# 35   c036  06/12/24  acceso a propiedad privada              el valle
# 36   c037  07/12/24  acceso a propiedad privada              el valle
#
#           estado impacto
# 0       resuelto    alto
# 1       resuelto   medio
# 2       resuelto   medio
# 3       resuelto   medio
# 4   sin resolver    alto
# 5   sin resolver    alto
# 6       resuelto    bajo
# 7       resuelto    alto
# 8   sin resolver    alto
# 9   sin resolver    alto
# 10  sin resolver    alto
# 11  sin resolver    alto
# 12  sin resolver    alto
# 13      resuelto   medio
# 14      resuelto   medio
# 15  sin resolver    alto
# 16  sin resolver    alto
# 17  sin resolver    alto
# 18  sin resolver    alto
# 19      resuelto    bajo
# 20      resuelto    bajo
# 21      resuelto    bajo
# 22      resuelto    bajo
# 23  sin resolver    alto
# 24  sin resolver    alto
# 25  sin resolver    alto
# 26  sin resolver    alto
# 27  sin resolver    alto
# 28  sin resolver    alto
# 29    en proceso    alto
# 30  sin resolver    alto
# 31  sin resolver    alto
# 32  sin resolver    alto
# 33  sin resolver    alto
# 34      resuelto    bajo
# 35      resuelto    bajo
# 36      resuelto    bajo

# %%
df["estado"].head()
# Out:
# 0        resuelto
# 1        resuelto
# 2        resuelto
# 3        resuelto
# 4    sin resolver
# Name: estado, dtype: object

# %%
df["ubicación"].head()
# Out:
# 0    merida casco central
# 1    merida casco central
# 2    merida casco central
# 3    merida casco central
# 4            los sausales
# Name: ubicación, dtype: object

# %%
#filtrado por texto

df[df["ubicación"]== "el valle"].head()
# Out:
#    codigo     fecha                 descripcion ubicación    estado impacto
# 6    c007  07/11/24  acceso a propiedad privada  el valle  resuelto    bajo
# 13   c014  14/11/24                       hurto  el valle  resuelto   medio
# 14   c015  15/11/24                       hurto  el valle  resuelto   medio
# 19   c020  20/11/24  acceso a propiedad privada  el valle  resuelto    bajo
# 20   c021  21/11/24  acceso a propiedad privada  el valle  resuelto    bajo

# %%
#filtrado combinado

df[(df["impacto"]== "medio") & (df["ubicación"] =="el valle")].head()
# Out:
#    codigo     fecha descripcion ubicación    estado impacto
# 13   c014  14/11/24       hurto  el valle  resuelto   medio
# 14   c015  15/11/24       hurto  el valle  resuelto   medio
