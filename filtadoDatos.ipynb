# %%
import pandas as pd

df = pd.read_csv("/home/jdata/Escritorio/projects/cursoDataScience/VehicleCrashes.csv", nrows = 100)
df.head(10)
# Out:
#    CRASH DATE CRASH TIME   BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 0  09/11/2021       2:39       NaN       NaN        NaN        NaN
# 1  03/26/2022      11:45       NaN       NaN        NaN        NaN
# 2  11/01/2023       1:29  BROOKLYN   11230.0  40.621790 -73.970024
# 3  06/29/2022       6:55       NaN       NaN        NaN        NaN
# 4  09/21/2022      13:21       NaN       NaN        NaN        NaN
# 5  04/26/2023      13:30       NaN       NaN        NaN        NaN
# 6  11/01/2023       7:12       NaN       NaN        NaN        NaN
# 7  11/01/2023       8:01       NaN       NaN        NaN        NaN
# 8  04/26/2023      22:20       NaN       NaN        NaN        NaN
# 9  09/11/2021       9:35  BROOKLYN   11208.0  40.667202 -73.866500
#
#                  LOCATION            ON STREET NAME   CROSS STREET NAME  \
# 0                     NaN     WHITESTONE EXPRESSWAY           20 AVENUE
# 1                     NaN   QUEENSBORO BRIDGE UPPER                 NaN
# ...

# %%
df["LATITUDE"].head()
# Out:
# 0         NaN
# 1         NaN
# 2    40.62179
# 3         NaN
# 4         NaN
# Name: LATITUDE, dtype: float64

# %%
df["CRASH TIME"].head()
# Out:
# 0     2:39
# 1    11:45
# 2     1:29
# 3     6:55
# 4    13:21
# Name: CRASH TIME, dtype: object

# %%
#filtrado por texto

df[df["CROSS STREET NAME"]== "20 AVENUE"].head()
# Out:
#    CRASH DATE CRASH TIME BOROUGH  ZIP CODE  LATITUDE  LONGITUDE LOCATION  \
# 0  09/11/2021       2:39     NaN       NaN       NaN        NaN      NaN
#
#           ON STREET NAME CROSS STREET NAME OFF STREET NAME  ...  \
# 0  WHITESTONE EXPRESSWAY         20 AVENUE             NaN  ...
#
#    CONTRIBUTING FACTOR VEHICLE 2  CONTRIBUTING FACTOR VEHICLE 3  \
# 0                    Unspecified                            NaN
#
#    CONTRIBUTING FACTOR VEHICLE 4  CONTRIBUTING FACTOR VEHICLE 5  COLLISION_ID  \
# 0                            NaN                            NaN       4455765
#
#    VEHICLE TYPE CODE 1  VEHICLE TYPE CODE 2  VEHICLE TYPE CODE 3  \
# 0                Sedan                Sedan                  NaN
#
#   VEHICLE TYPE CODE 4 VEHICLE TYPE CODE 5
# 0                 NaN                 NaN
#
# [1 rows x 29 columns]

# %%
#filtrado combinado

df[(df["CROSS STREET NAME"]== "20 AVENUE") & (df["CROSS STREET NAME"] =="AVENUE K")].head()
# Out:
# Empty DataFrame
# Columns: [CRASH DATE, CRASH TIME, BOROUGH, ZIP CODE, LATITUDE, LONGITUDE, LOCATION, ON STREET NAME, CROSS STREET NAME, OFF STREET NAME, NUMBER OF PERSONS INJURED, NUMBER OF PERSONS KILLED, NUMBER OF PEDESTRIANS INJURED, NUMBER OF PEDESTRIANS KILLED, NUMBER OF CYCLIST INJURED, NUMBER OF CYCLIST KILLED, NUMBER OF MOTORIST INJURED, NUMBER OF MOTORIST KILLED, CONTRIBUTING FACTOR VEHICLE 1, CONTRIBUTING FACTOR VEHICLE 2, CONTRIBUTING FACTOR VEHICLE 3, CONTRIBUTING FACTOR VEHICLE 4, CONTRIBUTING FACTOR VEHICLE 5, COLLISION_ID, VEHICLE TYPE CODE 1, VEHICLE TYPE CODE 2, VEHICLE TYPE CODE 3, VEHICLE TYPE CODE 4, VEHICLE TYPE CODE 5]
# Index: []
#
# [0 rows x 29 columns]
