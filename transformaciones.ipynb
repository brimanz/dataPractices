# %%
import pandas as pd
df = pd.read_csv("/home/jdata/Escritorio/projects/dataAnalyst/dataPractices/VehicleCrashes.csv")

# %%
#borrando columnas en dataset

del(df["VEHICLE TYPE CODE 5"])

# %%
df.head()
# Out:
#    CRASH DATE CRASH TIME   BOROUGH ZIP CODE  LATITUDE  LONGITUDE  \
# 0  09/11/2021       2:39       NaN      NaN       NaN        NaN
# 1  03/26/2022      11:45       NaN      NaN       NaN        NaN
# 2  11/01/2023       1:29  BROOKLYN  11230.0  40.62179 -73.970024
# 3  06/29/2022       6:55       NaN      NaN       NaN        NaN
# 4  09/21/2022      13:21       NaN      NaN       NaN        NaN
#
#                  LOCATION           ON STREET NAME CROSS STREET NAME  \
# 0                     NaN    WHITESTONE EXPRESSWAY         20 AVENUE
# 1                     NaN  QUEENSBORO BRIDGE UPPER               NaN
# 2  (40.62179, -73.970024)            OCEAN PARKWAY          AVENUE K
# 3                     NaN       THROGS NECK BRIDGE               NaN
# 4                     NaN          BROOKLYN BRIDGE               NaN
#
#   OFF STREET NAME  ...  CONTRIBUTING FACTOR VEHICLE 1  \
# 0             NaN  ...   Aggressive Driving/Road Rage
# ...

# %%
#borrando un grupo de columnas dentro del dataset

df = df.drop(["VEHICLE TYPE CODE 3", "VEHICLE TYPE CODE 4"], axis=1)

# %%
df.head()
# Out:
#    CRASH DATE CRASH TIME   BOROUGH ZIP CODE  LATITUDE  LONGITUDE  \
# 0  09/11/2021       2:39       NaN      NaN       NaN        NaN
# 1  03/26/2022      11:45       NaN      NaN       NaN        NaN
# 2  11/01/2023       1:29  BROOKLYN  11230.0  40.62179 -73.970024
# 3  06/29/2022       6:55       NaN      NaN       NaN        NaN
# 4  09/21/2022      13:21       NaN      NaN       NaN        NaN
#
#                  LOCATION           ON STREET NAME CROSS STREET NAME  \
# 0                     NaN    WHITESTONE EXPRESSWAY         20 AVENUE
# 1                     NaN  QUEENSBORO BRIDGE UPPER               NaN
# 2  (40.62179, -73.970024)            OCEAN PARKWAY          AVENUE K
# 3                     NaN       THROGS NECK BRIDGE               NaN
# 4                     NaN          BROOKLYN BRIDGE               NaN
#
#   OFF STREET NAME  ...  NUMBER OF MOTORIST INJURED  NUMBER OF MOTORIST KILLED  \
# ...

# %%
#otra manera de borrar elementos
#df = df.drop(["VEHICLE TYPE CODE 3", "VEHICLE TYPE CODE 4"], axis=1, inplace=1)

# %%
#eliminando filas
df.drop(0)
# Out:
#          CRASH DATE CRASH TIME    BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 1        03/26/2022      11:45        NaN      NaN        NaN        NaN
# 2        11/01/2023       1:29   BROOKLYN  11230.0  40.621790 -73.970024
# 3        06/29/2022       6:55        NaN      NaN        NaN        NaN
# 4        09/21/2022      13:21        NaN      NaN        NaN        NaN
# 5        04/26/2023      13:30        NaN      NaN        NaN        NaN
# ...             ...        ...        ...      ...        ...        ...
# 2159877  03/03/2025       9:05        NaN      NaN  40.605568 -74.031180
# 2159878  02/19/2025       9:48  MANHATTAN  10019.0  40.767930 -73.990000
# 2159879  03/02/2025       7:16  MANHATTAN  10075.0  40.773018 -73.952190
# 2159880  02/11/2025      11:06     QUEENS  11101.0  40.743790 -73.926506
# 2159881  03/03/2025       7:16        NaN      NaN  40.778492 -73.925830
#
#                        LOCATION           ON STREET NAME CROSS STREET NAME  \
# ...

# %%
df.head()
# Out:
#    CRASH DATE CRASH TIME   BOROUGH ZIP CODE  LATITUDE  LONGITUDE  \
# 0  09/11/2021       2:39       NaN      NaN       NaN        NaN
# 1  03/26/2022      11:45       NaN      NaN       NaN        NaN
# 2  11/01/2023       1:29  BROOKLYN  11230.0  40.62179 -73.970024
# 3  06/29/2022       6:55       NaN      NaN       NaN        NaN
# 4  09/21/2022      13:21       NaN      NaN       NaN        NaN
#
#                  LOCATION           ON STREET NAME CROSS STREET NAME  \
# 0                     NaN    WHITESTONE EXPRESSWAY         20 AVENUE
# 1                     NaN  QUEENSBORO BRIDGE UPPER               NaN
# 2  (40.62179, -73.970024)            OCEAN PARKWAY          AVENUE K
# 3                     NaN       THROGS NECK BRIDGE               NaN
# 4                     NaN          BROOKLYN BRIDGE               NaN
#
#   OFF STREET NAME  ...  NUMBER OF MOTORIST INJURED  NUMBER OF MOTORIST KILLED  \
# ...
